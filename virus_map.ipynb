# %%
import pandas as pd
import requests

# beautifulsoup4 can be used to precisely scrape data from the web page, but let's try read_html().
r = requests.get("https://www.worldometers.info/coronavirus/")

df = pd.read_html(r.text)

# %%
print(type(df))
print(len(df))
# Out:
# <class 'list'>
# 2

# %%
df[0]
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                    World     1853155     898.0     114247.0       53.0
# 1                      USA      560433     133.0      22115.0       10.0
# 2                    Spain      166831       NaN      17209.0        NaN
# 3                    Italy      156363       NaN      19899.0        NaN
# 4                   France      132591       NaN      14393.0        NaN
# ..                     ...         ...       ...          ...        ...
# 209            Timor-Leste           2       NaN          NaN        NaN
# 210  Saint Pierre Miquelon           1       NaN          NaN        NaN
# 211                  Yemen           1       NaN          NaN        NaN
# 212                  China       82160     108.0       3341.0        2.0
# 213                 Total:     1853155     898.0     114247.0       53.0
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0          423625.0      1315283           50853.0            238.00
# 1           32634.0       505684           11766.0           1693.00
# 2           62391.0        87231            7371.0           3568.00
# 3           34211.0       102253            3343.0           2586.00
# 4           27186.0        91012            6845.0           2031.00
# ..              ...          ...               ...               ...
# 209             1.0            1               NaN              2.00
# 210             NaN            1               NaN            173.00
# 211             NaN            1               NaN              0.03
# 212         77663.0         1156             121.0             57.00
# 213        423625.0      1315283           50853.0            237.70
#
#      Deaths/1M pop  TotalTests  Tests/ 1M pop
# 0             14.7         NaN            NaN
# 1             67.0   2832539.0         8557.0
# 2            368.0    600000.0        12833.0
# 3            329.0   1010193.0        16708.0
# 4            221.0    333807.0         5114.0
# ..             ...         ...            ...
# 209            NaN         NaN            NaN
# 210            NaN         NaN            NaN
# 211            NaN         NaN            NaN
# 212            2.0         NaN            NaN
# 213           14.7         NaN            NaN
#
# [214 rows x 12 columns]

# %%
df[1]
# Out:
#              Country,Other  TotalCases NewCases  TotalDeaths NewDeaths  \
# 0                    World     1852257  +72,514     114194.0    +5,415
# 1                    China       82052      +99       3339.0       NaN
# 2                      USA      560300  +27,421      22105.0    +1,528
# 3                    Spain      166831   +3,804      17209.0      +603
# 4                    Italy      156363   +4,092      19899.0      +431
# ..                     ...         ...      ...          ...       ...
# 209       Papua New Guinea           2      NaN          NaN       NaN
# 210            Timor-Leste           2      NaN          NaN       NaN
# 211  Saint Pierre Miquelon           1      NaN          NaN       NaN
# 212                  Yemen           1      NaN          NaN       NaN
# 213                 Total:     1852257  +72,514     114194.0    +5,415
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0          423311.0      1314752           50776.0            238.00
# 1           77575.0         1138             139.0             57.00
# 2           32634.0       505561           11766.0           1693.00
# 3           62391.0        87231            7371.0           3568.00
# 4           34211.0       102253            3343.0           2586.00
# ..              ...          ...               ...               ...
# 209             NaN            2               NaN              0.20
# 210             1.0            1               NaN              2.00
# 211             NaN            1               NaN            173.00
# 212             NaN            1               NaN              0.03
# 213        423311.0      1314752           50776.0            237.60
#
#      Deaths/1M pop  TotalTests  Tests/ 1M pop
# 0             14.7         NaN            NaN
# 1              2.0         NaN            NaN
# 2             67.0   2832258.0         8557.0
# 3            368.0    355000.0         7593.0
# 4            329.0   1010193.0        16708.0
# ..             ...         ...            ...
# 209            NaN        72.0            8.0
# 210            NaN         NaN            NaN
# 211            NaN         NaN            NaN
# 212            NaN         NaN            NaN
# 213           14.7         NaN            NaN
#
# [214 rows x 12 columns]

# %% [markdown]
# Ha? The same DataFrame twice?

# %%
df_data = df[0].loc[:, ['Country,Other', 'TotalCases', 'TotalDeaths']]
df_data
# Out:
#              Country,Other  TotalCases  TotalDeaths
# 0                    World     1853155     114247.0
# 1                      USA      560433      22115.0
# 2                    Spain      166831      17209.0
# 3                    Italy      156363      19899.0
# 4                   France      132591      14393.0
# ..                     ...         ...          ...
# 209            Timor-Leste           2          NaN
# 210  Saint Pierre Miquelon           1          NaN
# 211                  Yemen           1          NaN
# 212                  China       82160       3341.0
# 213                 Total:     1853155     114247.0
#
# [214 rows x 3 columns]
