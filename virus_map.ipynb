# %%
import pandas as pd
import requests

# beautifulsoup4 can be used to precisely scrape data from the web page, but let's try read_html().
r = requests.get("https://www.worldometers.info/coronavirus/")

df = pd.read_html(r.text)

# %%
print(type(df))
print(len(df))
# Out:
# <class 'list'>
# 2

# %%
df[0]
# Out:
#              Country,Other  TotalCases NewCases  TotalDeaths NewDeaths  \
# 0                    World     2359332  +28,566     161950.0    +1,903
# 1                      USA      740151   +1,359      39068.0       +54
# 2                    Spain      195944   +1,528      20453.0      +410
# 3                    Italy      175925      NaN      23227.0       NaN
# 4                   France      151793      NaN      19323.0       NaN
# ..                     ...         ...      ...          ...       ...
# 209               Anguilla           3      NaN          NaN       NaN
# 210  Saint Pierre Miquelon           1      NaN          NaN       NaN
# 211                  Yemen           1      NaN          NaN       NaN
# 212                  China       82735      +16       4632.0       NaN
# 213                 Total:     2359332  +28,566     161950.0    +1,903
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0          606675.0      1590707           54526.0            303.00
# 1           68456.0       632627           13551.0           2236.00
# 2           77357.0        98134            7371.0           4191.00
# 3           44927.0       107771            2733.0           2910.00
# 4           35983.0        96487            5833.0           2325.00
# ..              ...          ...               ...               ...
# 209             1.0            2               NaN            200.00
# 210             NaN            1               NaN            173.00
# 211             NaN            1               NaN              0.03
# 212         77062.0         1041              85.0             57.00
# 213        606675.0      1590707           54526.0            302.70
#
#      Deaths/1M pop  TotalTests  Tests/ 1M pop
# 0             20.8         NaN            NaN
# 1            118.0   3732979.0        11278.0
# 2            437.0    930230.0        19896.0
# 3            384.0   1305833.0        21598.0
# 4            296.0    463662.0         7103.0
# ..             ...         ...            ...
# 209            NaN         NaN            NaN
# 210            NaN         NaN            NaN
# 211            NaN         NaN            NaN
# 212            3.0         NaN            NaN
# 213           20.8         NaN            NaN
#
# [214 rows x 12 columns]

# %%
df[1]
# Out:
#              Country,Other  TotalCases NewCases  TotalDeaths NewDeaths  \
# 0                    World     2330766  +81,903     160047.0    +5,909
# 1                    China       82719      +27       4632.0       NaN
# 2                      USA      738792  +29,057      39014.0    +1,867
# 3                    Spain      194416   +3,577      20043.0       +41
# 4                    Italy      175925   +3,491      23227.0      +482
# ..                     ...         ...      ...          ...       ...
# 209               Anguilla           3      NaN          NaN       NaN
# 210  Caribbean Netherlands           3      NaN          NaN       NaN
# 211  Saint Pierre Miquelon           1      NaN          NaN       NaN
# 212                  Yemen           1      NaN          NaN       NaN
# 213                 Total:     2330766  +81,903     160047.0    +5,909
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0          596482.0      1574237           55265.0            299.00
# 1           77029.0         1058              85.0             57.00
# 2           68269.0       631509           13551.0           2232.00
# 3           74797.0        99576            7371.0           4158.00
# 4           44927.0       107771            2733.0           2910.00
# ..              ...          ...               ...               ...
# 209             1.0            2               NaN            200.00
# 210             NaN            3               NaN            114.00
# 211             NaN            1               NaN            173.00
# 212             NaN            1               NaN              0.03
# 213        596482.0      1574237           55265.0            299.00
#
#      Deaths/1M pop  TotalTests  Tests/ 1M pop
# 0             20.5         NaN            NaN
# 1              3.0         NaN            NaN
# 2            118.0   3722145.0        11245.0
# 3            429.0    930230.0        19896.0
# 4            384.0   1305833.0        21598.0
# ..             ...         ...            ...
# 209            NaN         NaN            NaN
# 210            NaN        10.0          381.0
# 211            NaN         NaN            NaN
# 212            NaN         NaN            NaN
# 213           20.5         NaN            NaN
#
# [214 rows x 12 columns]

# %% [markdown]
# WHAT? The same DataFrame twice? The exact replica.

# %%
df_virus_data = df[0].loc[:, ["Country,Other", "TotalCases", "TotalDeaths"]]

df_virus_data = df_virus_data.rename(columns={"Country,Other":"Country",
                   "TotalCases":"Cases",
                   "TotalDeaths":"Deaths"})
df_virus_data
# Out:
#                    Country    Cases    Deaths
# 0                    World  2359332  161950.0
# 1                      USA   740151   39068.0
# 2                    Spain   195944   20453.0
# 3                    Italy   175925   23227.0
# 4                   France   151793   19323.0
# ..                     ...      ...       ...
# 209               Anguilla        3       NaN
# 210  Saint Pierre Miquelon        1       NaN
# 211                  Yemen        1       NaN
# 212                  China    82735    4632.0
# 213                 Total:  2359332  161950.0
#
# [214 rows x 3 columns]

# %%
# Drop the rows for 'World' and 'Total:'
df_virus_data = df_virus_data[df_virus_data['Country']!='World']
df_virus_data = df_virus_data[df_virus_data['Country']!='Total:']                              
df_virus_data
# Out:
#                    Country   Cases   Deaths
# 1                      USA  740151  39068.0
# 2                    Spain  195944  20453.0
# 3                    Italy  175925  23227.0
# 4                   France  151793  19323.0
# 5                  Germany  144348   4547.0
# ..                     ...     ...      ...
# 208            South Sudan       4      NaN
# 209               Anguilla       3      NaN
# 210  Saint Pierre Miquelon       1      NaN
# 211                  Yemen       1      NaN
# 212                  China   82735   4632.0
#
# [212 rows x 3 columns]

# %%
# Source: https://simplemaps.com/static/data/world-cities/basic/simplemaps_worldcities_basicv1.6.zip
df_geolocation = pd.read_csv('./worldcities.csv')

# %%
# Only primary capitals, otherwise administrative ones e.g., Sao Paulo and Shanghai would be included
df_geolocation = df_geolocation[df_geolocation['capital']=='primary']
df_geolocation
# Out:
#              city    city_ascii      lat       lng       country iso2 iso3  \
# 0           Tokyo         Tokyo  35.6850  139.7514         Japan   JP  JPN
# 2     Mexico City   Mexico City  19.4424  -99.1310        Mexico   MX  MEX
# 9           Dhaka         Dhaka  23.7231   90.4086    Bangladesh   BD  BGD
# 10   Buenos Aires  Buenos Aires -34.6025  -58.3975     Argentina   AR  ARG
# 12          Cairo         Cairo  30.0500   31.2500         Egypt   EG  EGY
# ..            ...           ...      ...       ...           ...  ...  ...
# 600       Al Quds       Al Quds  31.7764   35.2269     West Bank   XW  XWB
# 601   Philipsburg   Philipsburg  18.0255  -63.0450  Sint Maarten   SX  SXM
# 602        Gitega        Gitega  -3.4271   29.9246       Burundi   BI  BDI
# 603      Pristina      Pristina  42.6666   21.1724        Kosovo   XK  XKS
# 604     Ngerulmud     Ngerulmud   7.5000  134.6242         Palau   PW  PLW
#
#                            admin_name  capital  population          id
# 0                               Tōkyō  primary  35676000.0  1392685764
# 2                    Ciudad de México  primary  19028000.0  1484247881
# 9                               Dhaka  primary  12797394.0  1050529279
# 10   Buenos Aires, Ciudad Autónoma de  primary  12795000.0  1032717330
# 12                         Al Qāhirah  primary  11893000.0  1818253931
# ..                                ...      ...         ...         ...
# 600                               NaN  primary         NaN  1934000006
# 601                               NaN  primary         NaN  1534859858
# 602                            Gitega  primary         NaN  1108778000
# 603                         Prishtinë  primary         NaN  1901760068
# 604                          Melekeok  primary         NaN  1585525081
#
# [212 rows x 11 columns]

# %%
# Check if each virus country name is indeed included in the geolocation file
virus_country_list = df_virus_data['Country'].tolist()

geolocation_country_list = df_geolocation['country'].tolist()

cities_not_inlcuded_list = []

print("*** NOT included in the geolocation database ***")
for virus_country in virus_country_list:
    if virus_country not in geolocation_country_list:
        cities_not_inlcuded_list.append(virus_country)
        
print(tuple(cities_not_inlcuded_list)) # Taking less space in printing below, rather than print(cities_not_inlcuded_list)
# United States
# United Kingdom
# Korea, South
# United Arab Emirates
# Bosnia And Herzegovina
# Out:
# *** NOT included in the geolocation database ***
# ('USA', 'UK', 'S. Korea', 'UAE', 'Bosnia and Herzegovina', 'North Macedonia', 'Hong Kong', 'Ivory Coast', 'Diamond Princess', 'Channel Islands', 'Palestine', 'Réunion', 'DRC', 'Isle of Man', 'Mayotte', 'Faeroe Islands', 'Martinique', 'Guadeloupe', 'Congo', 'Gibraltar', 'Trinidad and Tobago', 'Myanmar', 'French Guiana', 'Bermuda', 'Cayman Islands', 'Bahamas', 'French Polynesia', 'Macao', 'Saint Martin', 'Antigua and Barbuda', 'Eswatini', 'New Caledonia', 'Saint Kitts and Nevis', 'CAR', 'St. Vincent Grenadines', 'Turks and Caicos', 'Falkland Islands', 'Greenland', 'Montserrat', 'MS Zaandam', 'Gambia', 'Vatican City', 'St. Barth', 'Western Sahara', 'Caribbean Netherlands', 'British Virgin Islands', 'Sao Tome and Principe', 'Anguilla', 'Saint Pierre Miquelon')

# %%
# 'On' keyword preserves the index (1 - 212) of df_data, the caller's Dataframe
df_joined = df_virus_data.join(df_geolocation.set_index('country'), on='Country')
df_joined
# Out:
#                    Country   Cases   Deaths     city city_ascii      lat  \
# 1                      USA  740151  39068.0      NaN        NaN      NaN
# 2                    Spain  195944  20453.0   Madrid     Madrid  40.4000
# 3                    Italy  175925  23227.0     Rome       Rome  41.8960
# 4                   France  151793  19323.0    Paris      Paris  48.8667
# 5                  Germany  144348   4547.0   Berlin     Berlin  52.5218
# ..                     ...     ...      ...      ...        ...      ...
# 208            South Sudan       4      NaN     Juba       Juba   4.8300
# 209               Anguilla       3      NaN      NaN        NaN      NaN
# 210  Saint Pierre Miquelon       1      NaN      NaN        NaN      NaN
# 211                  Yemen       1      NaN    Sanaa      Sanaa  15.3547
# 212                  China   82735   4632.0  Beijing    Beijing  39.9289
#
#           lng iso2 iso3         admin_name  capital  population            id
# 1         NaN  NaN  NaN                NaN      NaN         NaN           NaN
# 2     -3.6834   ES  ESP             Madrid  primary   5567000.0  1.724617e+09
# 3     12.4833   IT  ITA              Lazio  primary   3339000.0  1.380383e+09
# 4      2.3333   FR  FRA      Île-de-France  primary   9904000.0  1.250015e+09
# 5     13.4015   DE  DEU             Berlin  primary   3406000.0  1.276451e+09
# ..        ...  ...  ...                ...      ...         ...           ...
# 208   31.5800   SS  SSD  Central Equatoria  primary    111975.0  1.728444e+09
# 209       NaN  NaN  NaN                NaN      NaN         NaN           NaN
# 210       NaN  NaN  NaN                NaN      NaN         NaN           NaN
# 211   44.2066   YE  YEM  Amānat al ‘Āşimah  primary   2008000.0  1.887751e+09
# 212  116.3883   CN  CHN            Beijing  primary  11106000.0  1.156229e+09
#
# [220 rows x 13 columns]

# %%
import datetime as dt

time_stamp =dt.datetime.now().strftime('%Y%m%d%H%M%S%z')

# The name of data file uploaded via gis.content.add (later on) has to be seemingly unique 
joined_data_file_name = 'joined_data'+time_stamp+'.csv'
df_joined.to_csv(joined_data_file_name, index=False)

# %%
#import os
#import zipfile
#from copy import deepcopy
#import arcpy
# from arcgis.features import GeoAccessor
import ruamel.yaml as yaml
from arcgis.gis import GIS


with open("arcgis_login.yaml") as stream:
    try:
        arc_gis_login_dict = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print("YAML reading error")
# Out:
# /home/to/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/features/_data/geodataset/utils.py:16: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime,

# %%
gis = GIS(arc_gis_login_dict["dev_account"]['url'], 
        arc_gis_login_dict["dev_account"]['username'],
        arc_gis_login_dict["dev_account"]['password'])

# %%
gis.users.me.folders
# Out:
# [{'username': 'tezzy_o',
#   'id': '24dea461778d46e08c66875d785d3be8',
#   'title': 'CoronaVirus',
#   'created': 1587078553000}]

# %%
folder_name = 'CoronaVirus'
file_extension = 'CSV' # Must to be all UPPER cases, not 'csv': Otherwise "Item type not valid."
full_path_name = !pwd # IPython.utils.text.SList
full_path_name = str(full_path_name[0]) + '/'

corona_virus_props = {"title":"Corona_Virus_"+time_stamp,
                   "type":file_extension,
                   "tags":"Corona Virus, World, Cases, Deaths",
                   "snippet":"Corona virus cases and deaths by country.",
                   "description":"Data downloaded from worldometers: COVID-19 \
                   Corona Virus Pandemic https://www.worldometers.info/coronavirus/"}

# Not sure why we need this as the ArcGIS Online does not show Folders at all
if not folder_name in [folder['title'] for folder in gis.users.me.folders]:
    gis.content.create_folder(folder_name)

corona_virus_props_data_item = gis.content.add(item_properties=corona_virus_props, 
                                               data=full_path_name+joined_data_file_name, 
                                               folder=folder_name)
corona_virus_props_item = corona_virus_props_data_item.publish()
corona_virus_props_item.id
# Out:
# Item type not valid.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-e09c79071eb8> in <module>
#      17 corona_virus_props_data_item = gis.content.add(item_properties=corona_virus_props,
#      18                                                data=full_path_name+joined_data_file_name,
# ---> 19                                                folder=folder_name)
#      20 corona_virus_props_item = corona_virus_props_data_item.publish()
#      21 corona_virus_props_item.id
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/gis/__init__.py in add(self, item_properties, data, thumbnail, metadata, owner, folder)
#    3195             itemid = self._portal.add_item(item_properties, data,
#    3196                                            thumbnail, metadata,
# -> 3197                                            owner_name, folder)
#    3198
#    3199         if itemid is not None:
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/_impl/portalpy.py in add_item(self, item_properties, data, thumbnail, metadata, owner, folder)
#     318
#     319         path += '/addItem'
# --> 320         resp = self.con.post(path, postdata, files)
#     321         if resp and resp.get('success'):
#     322             return resp['id']
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/_impl/connection.py in post(self, path, postdata, files, ssl, compress, is_retry, use_ordered_dict, add_token, verify_cert, token, try_json, out_folder, file_name, force_bytes, add_headers)
#    1157                                          verify_cert=verify_cert, is_retry=True)
#    1158
# -> 1159                 self._handle_json_error(resp_json['error'], errorcode)
#    1160                 return None
#    1161
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/_impl/connection.py in _handle_json_error(self, error, errorcode)
#    1178
#    1179         errormessage = errormessage + "\n(Error Code: " + str(errorcode) +")"
# -> 1180         raise RuntimeError(errormessage)
#    1181
#    1182 class _StrictURLopener(request.FancyURLopener):
#
# RuntimeError: Item type not valid.
# (Error Code: 400)

# %%
source_info = gis.content.analyze(item=corona_virus_props_item.id, file_type=file_extension, location_type='none')
source_info['publishParameters']
# Out:
# Unable to analyze item.
# Item type'url' is not supported for anzlyzing, The item needs to be of type file
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-4dea4689a773> in <module>
# ----> 1 source_info = gis.content.analyze(item=corona_virus_props_item.id, file_type='csv', location_type='none')
#       2 source_info['publishParameters']
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/gis/__init__.py in analyze(self, url, item, file_path, text, file_type, source_locale, geocoding_service, location_type, source_country, country_hint)
#    3304         gis = self._gis
#    3305         params['analyzeParameters'] = json.dumps(params['analyzeParameters'])
# -> 3306         return gis._con.post(path=surl, postdata=params, files=files)
#    3307
#    3308
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/_impl/connection.py in post(self, path, postdata, files, ssl, compress, is_retry, use_ordered_dict, add_token, verify_cert, token, try_json, out_folder, file_name, force_bytes, add_headers)
#    1157                                          verify_cert=verify_cert, is_retry=True)
#    1158
# -> 1159                 self._handle_json_error(resp_json['error'], errorcode)
#    1160                 return None
#    1161
#
# ~/miniconda3/envs/arcgis/lib/python3.7/site-packages/arcgis/_impl/connection.py in _handle_json_error(self, error, errorcode)
#    1178
#    1179         errormessage = errormessage + "\n(Error Code: " + str(errorcode) +")"
# -> 1180         raise RuntimeError(errormessage)
#    1181
#    1182 class _StrictURLopener(request.FancyURLopener):
#
# RuntimeError: Unable to analyze item.
# Item type'url' is not supported for anzlyzing, The item needs to be of type file
# (Error Code: 400)

# %%
df_joined.to_csv('./country_list.csv', index=False)

# %%
import arcgis
from arcgis.gis import GIS
from IPython.display import display

gis = GIS() # Connect to ArcGIS Online as an anonymous user
# search_subset = ago_gis.content.search("world") # , item_type = "Feature Layer")
search_subset = ago_gis.content.search('world', outside_org=True)



world_map = gis.map('world', 1)
world_map

layer = gis.content.get('f126c266cae74be4a06873b43684d294')

world_map.add_layer(layer)
# for it in search_subset:
#     display(it)

# subset_item = search_subset[0]
# subset_item

# %%
world_map.center = [7.793813, -173.102401] # [latitude, longitude]
world_map.zoom = 2
world_map
# Out:
# MapView(jupyter_target='notebook', layout=Layout(height='400px', width='100%'), ready=True, zoom=2.0)
# <div class="map-static-img-preview-c6e23c76-e66d-4316-a059-ca378c6fa148"><img src=""></img></div>

# %%
gis = GIS()
webmap = gis.content.get('41281c51f9de45edaf1c8ed44bb10e30')
webmap

# Import the WebMap class

# from the arcgis.mapping module and visualize the web map.

from arcgis.mapping import WebMap
la_parks_trails = WebMap(webmap)
la_parks_trails
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-dc69f2e9-b183-498b-8214-a850f4116b52"><img src=""></img></div>

# %%
operational_layers = la_parks_trails.layers
n = len(operational_layers)
print("The webmap has {} layers.".format(n))
# Out:
# The webmap has 4 layers.

# %%
for layer in operational_layers:
    print("{}\n\t{}".format(layer['id'], layer['url']))
# Out:
# Trailheads_8053
# 	https://services3.arcgis.com/GVgbJbqm8hXASVYi/arcgis/rest/services/Trailheads/FeatureServer/0
# Trails_7558_8861
# 	https://services3.arcgis.com/GVgbJbqm8hXASVYi/arcgis/rest/services/Trails/FeatureServer/0
# Trails_7558
# 	https://services3.arcgis.com/GVgbJbqm8hXASVYi/arcgis/rest/services/Trails/FeatureServer/0
# Parks_and_Open_Space_8268
# 	https://services3.arcgis.com/GVgbJbqm8hXASVYi/arcgis/rest/services/Parks_and_Open_Space/FeatureServer/0

# %%
# add the initial csv file and publish that as a web layer
item_prop = {'title':'USA Capitals spreadsheet ' + now_ts}
csv_item = gis.content.add(item_properties=item_prop, data=my_csv)
csv_item
